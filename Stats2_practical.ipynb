# %%
data=[23,24,32,45,12,43,67,45,32,56,32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy = data.copy()

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import seaborn as sns

# %%
sns.histplot(data_copy, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy.sort()

# %%
data_copy.append(179)

# %%
data_copy.append(210)

# %%
data_copy.append(290)

# %%
sns.histplot(data_copy, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy
#this is right skewed data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
#to create left skewed data
data_copy2 = data.copy()

# %%
data_copy2.insert(0,-10)

# %%
data_copy2.insert(0,-75)

# %%
data_copy2
# Out:
# [-75, -10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2, kde=True)
#left skewed
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
data2=pd.read_csv("iris.csv")

# %%
data2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data2["sepal_length"],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data2["sepal_width"],kde=True)
# its like normal dist data(about 90%)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data2["petal_width"],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
import numpy as np

# %%
normal_dist_data=np.random.normal(0.5,0.2,1000)
#mean and sd = 05, 0.2
#1000 data point

# %%
normal_dist_data
# Out:
# array([ 0.77579622,  0.42191961,  0.34623763,  0.31670665,  0.52305345,
#         0.52007838,  0.44772023,  0.63926684,  0.4524778 ,  0.57496597,
#         0.97598957,  0.7443891 ,  0.46186362,  0.30912447,  0.78804314,
#         0.72872186,  0.50375499,  0.72147862,  0.29489854,  0.18292021,
#         0.61004067,  0.27045279,  0.57386891,  0.28365942,  0.50316055,
#         0.68510647,  0.49297695,  0.46092121,  0.19010564,  0.58260045,
#         0.62055966,  0.33649653,  0.79694286,  0.73227588,  0.66531835,
#         0.49710318,  0.42898881,  0.39517489,  0.77716815,  0.39237196,
#         0.57375519,  0.61833408,  0.15627266,  0.43148403,  0.63338742,
#         0.26434295,  0.6816577 ,  0.71963022,  0.3248924 ,  0.61802381,
#         0.35668828,  0.67771414,  0.26866149,  0.70609657,  0.80389962,
#         0.61105809,  0.32891905,  0.43519161,  0.70298078,  0.54647037,
#         0.30917941,  0.97514594,  0.64143503,  0.19403617,  0.31695124,
# ...

# %%
sns.histplot(normal_dist_data,kde=True)
#complete normal dist data
# Out:
# <Axes: ylabel='Count'>

# %%
#generate log normal data

log_normal_dist_data = np.random.lognormal(0.5,0.2,1000)

# %%
sns.histplot(log_normal_dist_data,kde=True)
#it has tail
# Out:
# <Axes: ylabel='Count'>

# %%
log_normal_dist_data = np.random.lognormal(3.0,1.0,1000)

# %%
sns.histplot(log_normal_dist_data,kde=True)
#complete log normal dist data
# Out:
# <Axes: ylabel='Count'>

# %%
np.log(log_normal_dist_data)
#here will you get normally dist data
# Out:
# array([4.18449513, 4.70621297, 1.38679761, 3.98059599, 3.38589277,
#        1.63317361, 1.57265585, 3.7398401 , 3.19923653, 5.31278861,
#        2.50440781, 1.53347295, 1.2834028 , 3.35849204, 2.12360159,
#        3.98956956, 3.45334669, 3.6598475 , 5.03834572, 4.48082001,
#        4.40268081, 3.40250911, 3.20424818, 3.05522681, 3.96235231,
#        3.18469442, 4.7898753 , 2.98540606, 3.77410906, 1.4923798 ,
#        3.12923888, 3.39653326, 3.5966403 , 1.54255171, 2.44620178,
#        2.23908476, 2.44687718, 3.04741241, 4.31772122, 2.25025839,
#        1.9628556 , 5.13021794, 3.03624366, 2.92668283, 3.72938933,
#        4.6008763 , 3.2905552 , 2.02168717, 4.1709368 , 3.33054547,
#        3.45052999, 2.2274646 , 3.27035423, 3.4963647 , 3.05330935,
#        4.96465635, 1.88480144, 3.85357501, 2.49475089, 2.48725944,
#        3.3857007 , 4.41157884, 3.23136209, 3.16576572, 3.01732908,
#        2.2726203 , 4.0428174 , 4.92753619, 4.79878039, 3.24958149,
# ...

# %%
sns.histplot(np.log(log_normal_dist_data),kde=True)
#converted to ND, and if you have oulier you have to use lognormal , and then convert to normal
# Out:
# <Axes: ylabel='Count'>

# %%
##Q-Q PLOT -> quantile - quantile plot
#           -> compare theoratical and practicle

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

def plot_data(sample):
  plt.figure(figsize=(10,6))
  plt.subplot(1,2,1) #1st sub-plot
  sns.histplot(sample, kde=True)
  plt.subplot(1,2,2) #2nd sub-plot
  stat.probplot(sample,dist="norm",plot=pylab)
  plt.show()

# %%
plot_data(log_normal_dist_data)

# %%
plot_data(np.log(log_normal_dist_data))

# %%
#PDF --> prob dist f()
#1. PMF -> for discreate value
#        -> uniform, bernauli, binomial, poissn dist

#2. PDF -> for conti value
#        -> uniform, normal, standar normal dist, log-normal, powerlaw(80/20), pareto

# %%
from numpy import random
sns.distplot(random.uniform(size=500),hist=False)
#dist -> distribution plot and gives uniform dist data(wrt conti value)
# Out:
# <ipython-input-56-ca8aeb1d014b>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=500),hist=False)
# <Axes: ylabel='Density'>

# %%
np.random.randint(1,8,size=800)
#discreate variable
# Out:
# array([2, 1, 3, 6, 6, 7, 3, 3, 5, 5, 2, 1, 6, 4, 3, 7, 4, 1, 4, 2, 4, 6,
#        2, 7, 5, 4, 2, 3, 4, 1, 6, 2, 1, 3, 2, 4, 5, 4, 7, 2, 1, 1, 5, 4,
#        4, 6, 2, 1, 4, 2, 4, 1, 5, 2, 3, 1, 6, 5, 7, 3, 6, 2, 4, 6, 6, 5,
#        4, 4, 1, 1, 3, 1, 5, 1, 3, 2, 3, 2, 2, 4, 2, 1, 3, 3, 5, 4, 2, 3,
#        1, 7, 5, 4, 1, 5, 5, 5, 4, 4, 3, 5, 3, 6, 5, 6, 4, 1, 3, 3, 4, 1,
#        1, 7, 2, 7, 7, 6, 5, 7, 7, 1, 1, 7, 3, 2, 4, 6, 2, 3, 5, 7, 1, 1,
#        2, 7, 6, 1, 4, 2, 2, 4, 7, 1, 6, 5, 3, 6, 3, 4, 5, 3, 2, 1, 7, 7,
#        4, 3, 4, 5, 6, 3, 6, 2, 7, 3, 3, 5, 7, 4, 5, 4, 3, 7, 5, 2, 1, 2,
#        1, 1, 3, 6, 1, 1, 6, 3, 6, 2, 1, 5, 4, 1, 3, 1, 6, 3, 1, 3, 7, 5,
#        3, 4, 5, 4, 2, 6, 2, 4, 3, 5, 5, 4, 7, 2, 7, 2, 1, 4, 3, 4, 2, 5,
#        3, 6, 1, 6, 5, 6, 5, 7, 5, 4, 5, 1, 4, 6, 7, 7, 5, 4, 2, 3, 5, 7,
#        6, 2, 6, 3, 5, 4, 4, 4, 4, 6, 7, 6, 2, 6, 3, 4, 2, 2, 6, 3, 4, 3,
#        5, 7, 4, 4, 3, 4, 5, 1, 4, 4, 6, 3, 5, 4, 5, 6, 5, 7, 3, 3, 2, 6,
# ...

# %%
sns.histplot(np.random.randint(1,8,size=800))
#uniform dist
# Out:
# <Axes: ylabel='Count'>

# %%
#bernauli

# %%
p=0.3
sample_size=1000

bernauli_data = np.random.choice([0,1],size=sample_size,p=[1-p,p])

sns.histplot(bernauli_data, bins=2,kde=False,color="blue")
# Out:
# <Axes: ylabel='Count'>

# %%
#binomial dist

# %%
no_of_trial=10
prob = 0.5

data3 = np.random.binomial(no_of_trial,prob,10000)

# %%
sns.distplot(data3)
# Out:
# <ipython-input-63-6b5eda17f777>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data3)
# <Axes: ylabel='Density'>

# %%
#poisson dist

# %%
poisson_data = np.poisson(lam=5,size=1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-46c3a03388ee> in <cell line: 1>()
# ----> 1 poisson_data = np.poisson(lam=5,size=1000)
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     309             return Tester
#     310
# --> 311         raise AttributeError("module {!r} has no attribute "
#     312                              "{!r}".format(__name__, attr))
#     313
#
# AttributeError: module 'numpy' has no attribute 'poisson'

# %%
#CENTRAL LIMIT THEORAM -->

# %%
population = np.random.randint(10,20,50)

# %%
population
# Out:
# array([17, 16, 16, 10, 18, 12, 12, 16, 13, 14, 12, 10, 17, 16, 18, 11, 17,
#        12, 14, 17, 13, 16, 12, 16, 15, 15, 10, 13, 18, 19, 10, 11, 11, 12,
#        15, 13, 10, 12, 15, 10, 19, 16, 14, 16, 19, 12, 11, 16, 16, 18])

# %%
np.mean(population)
# Out:
# 14.22

# %%
np.median(population)
# Out:
# 14.5

# %%
from statistics import mode
mode(population)
# Out:
# 16

# %%
#take a random sample from population

# %%
np.random.choice(population, 20)
# Out:
# array([16, 16, 16, 18, 18, 14, 11, 11, 15, 15, 15, 10, 14, 16, 10, 12, 18,
#        19, 12, 11])

# %%
print(f"mean of the sample {np.mean(population)}")
# Out:
# mean of the sample 14.22

# %%
print(f"median of the sample {np.median(population)}")
# Out:
# median of the sample 14.5

# %%
print(f"mode of the sample {mode(population)}")
# Out:
# mode of the sample 16

# %%
#collect 4 sample

# %%
sample1 = np.random.choice(population,20)
sample2 = np.random.choice(population,20)
sample3 =np.random.choice(population,20)
sample4 = np.random.choice(population,20)

# %%
print(sample1)
print(60*"=")
print(sample2)
print(60*"=")
print(sample3)
print(60*"=")
print(sample4)
print(60*"=")
# Out:
# [16 12 19 13 18 19 15 12 18 10 15 19 18 16 10 15 16 12 16 14]
# ...
# [11 10 16 19 13 16 17 16 16 12 15 16 10 15 19 16 14 17 19 15]
# ...
# [12 13 11 16 14 10 16 12 18 12 16 17 10 18 16 19 10 15 16 18]
# ...
# [12 12 16 12 11 14 15 16 19 18 14 12 12 12 19 18 16 16 12 12]
# ...

# %%
mean_of_the_Sample = []
all_sample = [sample1,sample2,sample3,sample4]

for sample in all_sample:
  print(np.mean(sample))
# Out:
# 15.15
# 15.1
# 14.45
# 14.4

# %%
#actual CLT

# %%
population = np.random.binomial(10,0.5,10000)

# %%
len(population)
# Out:
# 10000

# %%
sns.distplot(population)
# Out:
# <ipython-input-93-8d1caca3cc70>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population)
# <Axes: ylabel='Density'>

# %%
size=int(len(population)*0.30)
print(size)
# Out:
# 3000

# %%
#collect the sample from data(30%)

sample_mean=[]

for i in range(1,31):
  sample = np.random.choice(population, size = size)
  sample_mean.append(np.mean(sample))

# %%
sample_mean
# Out:
# [4.931,
#  4.963666666666667,
#  4.981333333333334,
#  5.011,
#  5.024,
#  4.9526666666666666,
#  5.050333333333334,
#  4.954,
#  5.005333333333334,
#  4.975,
#  4.963333333333333,
#  4.96,
#  4.95,
#  5.005,
#  4.9463333333333335,
#  4.989,
#  4.963,
#  5.01,
#  4.979,
#  4.982333333333333,
#  4.971,
#  4.989333333333334,
#  4.989,
#  5.011666666666667,
#  4.973333333333334,
#  5.017666666666667,
#  5.03,
#  4.998333333333333,
#  5.009666666666667,
#  4.97]

# %%
sns.distplot(sample_mean)
# Out:
# <ipython-input-98-d196905dea46>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean)
# <Axes: ylabel='Density'>

# %%
#2:55
